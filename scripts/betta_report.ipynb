# %%
from daart_utils.reports import ReportGenerator

# %% [markdown]
# ### define paths

# %%
model_dir = '/Users/claireeverett/Desktop/Process_input/version_0'
features_dir = '/Users/claireeverett/Desktop/Process_input/for_daart/'
videos_dir = '/Users/claireeverett/Desktop/Process_input/videos/trim/'
save_dir = '/Users/claireeverett/Desktop/Process_input/daart_output/'
fig_format = 'pdf'
framerate = 40

# %% [markdown]
# ### run report

# %%
reporter = ReportGenerator(model_dir=model_dir)
reporter.generate_report(
    save_dir=save_dir,
    features_dir=features_dir,
    format=fig_format,
    bout_example_kwargs={
        'features_to_plot': ['orientation', 'operculum', 'oper_angle_avg', 'oper_dist_avg'],
        'frame_win': 200,
        'max_n_ex': 10,
        'min_bout_len': 5,
    },
    video_kwargs={
        'max_frames': 500,
        'framerate': 20,
    },
    video_framerate=framerate,
    videos_dir=videos_dir,
)
# Out:
# loading states from /Users/claireeverett/Desktop/Process_input/version_0/demo_R_states.npy...done
# /Users/claireeverett/Desktop/Process_input/scripts/daart_utils/plotting.py:631: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
#   fig.subplots_adjust(right=0.8)
# /Users/claireeverett/Desktop/Process_input/scripts/daart_utils/plotting.py:652: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/claireeverett/Desktop/Process_input/scripts/daart_utils/plotting.py:631: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
#   fig.subplots_adjust(right=0.8)
# /Users/claireeverett/Desktop/Process_input/scripts/daart_utils/plotting.py:652: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /Users/claireeverett/Desktop/Process_input/scripts/daart_utils/plotting.py:631: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
#   fig.subplots_adjust(right=0.8)
# /Users/claireeverett/Desktop/Process_input/scripts/daart_utils/plotting.py:652: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# 100%|██████████| 500/500 [00:45<00:00, 10.88it/s]
# ffmpeg -r 20.000000 -i /Users/claireeverett/Desktop/Process_input/daart_output/demo_R/tmpZzZ/frame_%06d.jpeg -c:v libx264 /Users/claireeverett/Desktop/Process_input/daart_output/demo_R/labeled_video.mp4
# 4it [00:03,  1.03it/s]
# creating animation...done
# saving video to /Users/claireeverett/Desktop/Process_input/daart_output/demo_R/syllable_video.mp4...done
# '/Users/claireeverett/Desktop/Process_input/daart_output/'
